# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %matplotlib inline

# %%
mnist = pd.read_csv("data/mnist1.5k.csv.gz", compression="gzip", header=None).values
X=mnist[:,1:785]/255.
y=mnist[:,0]
print "dimension de las imagenes y las clases", X.shape, y.shape
# Out:
# dimension de las imagenes y las clases (1500, 784) (1500,)

# %%
perm = np.random.permutation(range(X.shape[0]))[0:50]
random_imgs   = X[perm]
random_labels = y[perm] 
fig = plt.figure(figsize=(10,6))
for i in range(random_imgs.shape[0]):
    ax=fig.add_subplot(5,10,i+1)
    plt.imshow(random_imgs[i].reshape(28,28), interpolation="nearest", cmap = plt.cm.Greys_r)
    ax.set_title(int(random_labels[i]))
    ax.set_xticklabels([])
    ax.set_yticklabels([])

# %% [markdown]
# # Autoencoder for compression

# %%
from sklearn.model_selection import train_test_split
X_train, X_test = train_test_split(X, test_size=.2)

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten
from tensorflow.keras.backend import clear_session

# %%
def get_model_A(input_dim, hidden_size, code_size):
    clear_session()
    model = Sequential()
    model.add(Dense(hidden_size, activation='relu', input_dim=input_dim))
    model.add(Dense(code_size, activation='relu'))
    model.add(Dense(hidden_size, activation='relu'))
    model.add(Dense(input_dim, activation='sigmoid'))

    model.compile(optimizer='adam', loss='mean_squared_error')
    model.reset_states()
    return model

# %% [markdown]
# porqué sigmoide en la última capa. qué pasaría si ponemos tanh o linear

# %%
model = get_model_A(input_dim=X.shape[1], hidden_size=256, code_size=24)
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 256)               200960
# _________________________________________________________________
# dense_1 (Dense)              (None, 24)                6168
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               6400
# _________________________________________________________________
# dense_3 (Dense)              (None, 784)               201488
# =================================================================
# Total params: 415,016
# Trainable params: 415,016
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# try with larger layer, try with more layers

# %%
model.fit(X_train, X_train, epochs=100, batch_size=32)
# Out:
# Epoch 1/100
# 1200/1200 [==============================] - 0s 257us/step - loss: 0.1130
# Epoch 2/100
# 1200/1200 [==============================] - 0s 115us/step - loss: 0.0657
# Epoch 3/100
# 1200/1200 [==============================] - 0s 118us/step - loss: 0.0528
# Epoch 4/100
# 1200/1200 [==============================] - 0s 124us/step - loss: 0.0443
# Epoch 5/100
# 1200/1200 [==============================] - 0s 123us/step - loss: 0.0391
# Epoch 6/100
# 1200/1200 [==============================] - 0s 114us/step - loss: 0.0354
# Epoch 7/100
# 1200/1200 [==============================] - 0s 113us/step - loss: 0.0322
# Epoch 8/100
# 1200/1200 [==============================] - 0s 117us/step - loss: 0.0294
# Epoch 9/100
# 1200/1200 [==============================] - 0s 113us/step - loss: 0.0274
# Epoch 10/100
# 1200/1200 [==============================] - 0s 114us/step - loss: 0.0252
# Epoch 11/100
# 1200/1200 [==============================] - 0s 115us/step - loss: 0.0236
# Epoch 12/100
# 1200/1200 [==============================] - 0s 117us/step - loss: 0.0219
# Epoch 13/100
# 1200/1200 [==============================] - 0s 113us/step - loss: 0.0209
# Epoch 14/100
# 1200/1200 [==============================] - 0s 113us/step - loss: 0.0200
# Epoch 15/100
# 1200/1200 [==============================] - 0s 112us/step - loss: 0.0193
# Epoch 16/100
# 1200/1200 [==============================] - 0s 114us/step - loss: 0.0186
# Epoch 17/100
# 1200/1200 [==============================] - 0s 116us/step - loss: 0.0180
# Epoch 18/100
# 1200/1200 [==============================] - 0s 113us/step - loss: 0.0175
# Epoch 19/100
# 1200/1200 [==============================] - 0s 117us/step - loss: 0.0169
# Epoch 20/100
# 1200/1200 [==============================] - 0s 114us/step - loss: 0.0164
# Epoch 21/100
# 1200/1200 [==============================] - 0s 113us/step - loss: 0.0159
# Epoch 22/100
# 1200/1200 [==============================] - 0s 115us/step - loss: 0.0156
# Epoch 23/100
# 1200/1200 [==============================] - 0s 115us/step - loss: 0.0153
# Epoch 24/100
# 1200/1200 [==============================] - 0s 117us/step - loss: 0.0150
# Epoch 25/100
# 1200/1200 [==============================] - 0s 112us/step - loss: 0.0146
# Epoch 26/100
# 1200/1200 [==============================] - 0s 120us/step - loss: 0.0143
# Epoch 27/100
# 1200/1200 [==============================] - 0s 119us/step - loss: 0.0140
# Epoch 28/100
# 1200/1200 [==============================] - 0s 117us/step - loss: 0.0137
# Epoch 29/100
# 1200/1200 [==============================] - 0s 116us/step - loss: 0.0135
# Epoch 30/100
# 1200/1200 [==============================] - 0s 116us/step - loss: 0.0132
# Epoch 31/100
# 1200/1200 [==============================] - 0s 115us/step - loss: 0.0130
# Epoch 32/100
# 1200/1200 [==============================] - 0s 114us/step - loss: 0.0128
# Epoch 33/100
# 1200/1200 [==============================] - 0s 116us/step - loss: 0.0126
# Epoch 34/100
# 1200/1200 [==============================] - 0s 118us/step - loss: 0.0124
# Epoch 35/100
# 1200/1200 [==============================] - 0s 115us/step - loss: 0.0121
# Epoch 36/100
# 1200/1200 [==============================] - 0s 114us/step - loss: 0.0120
# Epoch 37/100
# 1200/1200 [==============================] - 0s 115us/step - loss: 0.0118
# Epoch 38/100
# 1200/1200 [==============================] - 0s 115us/step - loss: 0.0116
# Epoch 39/100
# 1200/1200 [==============================] - 0s 115us/step - loss: 0.0115
# Epoch 40/100
# 1200/1200 [==============================] - 0s 117us/step - loss: 0.0113
# Epoch 41/100
# 1200/1200 [==============================] - 0s 120us/step - loss: 0.0111
# Epoch 42/100
# 1200/1200 [==============================] - 0s 117us/step - loss: 0.0110
# Epoch 43/100
# 1200/1200 [==============================] - 0s 118us/step - loss: 0.0108
# Epoch 44/100
# 1200/1200 [==============================] - 0s 112us/step - loss: 0.0106
# Epoch 45/100
# 1200/1200 [==============================] - 0s 117us/step - loss: 0.0105
# Epoch 46/100
# 1200/1200 [==============================] - 0s 115us/step - loss: 0.0104
# Epoch 47/100
# 1200/1200 [==============================] - 0s 120us/step - loss: 0.0102
# Epoch 48/100
# 1200/1200 [==============================] - 0s 118us/step - loss: 0.0101
# Epoch 49/100
# 1200/1200 [==============================] - 0s 123us/step - loss: 0.0100
# Epoch 50/100
# 1200/1200 [==============================] - 0s 123us/step - loss: 0.0098
# Epoch 51/100
# 1200/1200 [==============================] - 0s 125us/step - loss: 0.0097
# Epoch 52/100
# 1200/1200 [==============================] - 0s 124us/step - loss: 0.0097
# Epoch 53/100
# 1200/1200 [==============================] - 0s 148us/step - loss: 0.0095
# Epoch 54/100
# 1200/1200 [==============================] - 0s 149us/step - loss: 0.0094
# Epoch 55/100
# 1200/1200 [==============================] - 0s 124us/step - loss: 0.0093
# Epoch 56/100
# 1200/1200 [==============================] - 0s 164us/step - loss: 0.0092
# Epoch 57/100
# 1200/1200 [==============================] - 0s 123us/step - loss: 0.0091
# Epoch 58/100
# 1200/1200 [==============================] - 0s 115us/step - loss: 0.0090
# Epoch 59/100
# 1200/1200 [==============================] - 0s 111us/step - loss: 0.0089
# Epoch 60/100
# 1200/1200 [==============================] - 0s 116us/step - loss: 0.0088
# Epoch 61/100
# 1200/1200 [==============================] - 0s 115us/step - loss: 0.0086
# Epoch 62/100
# 1200/1200 [==============================] - 0s 110us/step - loss: 0.0086
# Epoch 63/100
# 1200/1200 [==============================] - 0s 112us/step - loss: 0.0085
# Epoch 64/100
# 1200/1200 [==============================] - 0s 112us/step - loss: 0.0084
# Epoch 65/100
# 1200/1200 [==============================] - 0s 113us/step - loss: 0.0083
# Epoch 66/100
# 1200/1200 [==============================] - 0s 113us/step - loss: 0.0082
# Epoch 67/100
# 1200/1200 [==============================] - 0s 116us/step - loss: 0.0081
# Epoch 68/100
# 1200/1200 [==============================] - 0s 116us/step - loss: 0.0081
# Epoch 69/100
# 1200/1200 [==============================] - 0s 113us/step - loss: 0.0080
# Epoch 70/100
# 1200/1200 [==============================] - 0s 118us/step - loss: 0.0079
# Epoch 71/100
# 1200/1200 [==============================] - 0s 113us/step - loss: 0.0079
# Epoch 72/100
# 1200/1200 [==============================] - 0s 113us/step - loss: 0.0078
# Epoch 73/100
# 1200/1200 [==============================] - 0s 113us/step - loss: 0.0077
# Epoch 74/100
# 1200/1200 [==============================] - 0s 117us/step - loss: 0.0076
# Epoch 75/100
# 1200/1200 [==============================] - 0s 123us/step - loss: 0.0075
# Epoch 76/100
# 1200/1200 [==============================] - 0s 120us/step - loss: 0.0075
# Epoch 77/100
# 1200/1200 [==============================] - 0s 118us/step - loss: 0.0075
# Epoch 78/100
# 1200/1200 [==============================] - 0s 112us/step - loss: 0.0073
# Epoch 79/100
# 1200/1200 [==============================] - 0s 114us/step - loss: 0.0072
# Epoch 80/100
# 1200/1200 [==============================] - 0s 113us/step - loss: 0.0072
# Epoch 81/100
# 1200/1200 [==============================] - 0s 113us/step - loss: 0.0071
# Epoch 82/100
# 1200/1200 [==============================] - 0s 123us/step - loss: 0.0070
# Epoch 83/100
# 1200/1200 [==============================] - 0s 115us/step - loss: 0.0070
# Epoch 84/100
# 1200/1200 [==============================] - 0s 116us/step - loss: 0.0070
# Epoch 85/100
# 1200/1200 [==============================] - 0s 115us/step - loss: 0.0069
# Epoch 86/100
# 1200/1200 [==============================] - 0s 113us/step - loss: 0.0069
# Epoch 87/100
# 1200/1200 [==============================] - 0s 111us/step - loss: 0.0068
# Epoch 88/100
# 1200/1200 [==============================] - 0s 117us/step - loss: 0.0067
# Epoch 89/100
# 1200/1200 [==============================] - 0s 122us/step - loss: 0.0067
# Epoch 90/100
# 1200/1200 [==============================] - 0s 117us/step - loss: 0.0066
# Epoch 91/100
# 1200/1200 [==============================] - 0s 113us/step - loss: 0.0065
# Epoch 92/100
# 1200/1200 [==============================] - 0s 115us/step - loss: 0.0065
# Epoch 93/100
# 1200/1200 [==============================] - 0s 115us/step - loss: 0.0065
# Epoch 94/100
# 1200/1200 [==============================] - 0s 116us/step - loss: 0.0065
# Epoch 95/100
# 1200/1200 [==============================] - 0s 113us/step - loss: 0.0064
# Epoch 96/100
# 1200/1200 [==============================] - 0s 111us/step - loss: 0.0064
# Epoch 97/100
# 1200/1200 [==============================] - 0s 114us/step - loss: 0.0064
# Epoch 98/100
# 1200/1200 [==============================] - 0s 111us/step - loss: 0.0062
# Epoch 99/100
# 1200/1200 [==============================] - 0s 112us/step - loss: 0.0062
# Epoch 100/100
# 1200/1200 [==============================] - 0s 111us/step - loss: 0.0061

# %% [markdown]
# ### show reconstruction on sampled test images

# %%
X_sample = np.random.permutation(X_test)[:10]
X_pred   = model.predict(X_sample)

# %%
plt.figure(figsize=(20,5))
for i in range(len(X_sample)):
    plt.subplot(2,len(X_sample),i+1)
    plt.imshow(X_sample[i].reshape(28,28), cmap=plt.cm.Greys_r)
    plt.axis("off")
    plt.subplot(2,len(X_sample),len(X_sample)+i+1)
    plt.imshow(X_pred[i].reshape(28,28), cmap=plt.cm.Greys_r)
    plt.axis("off")

# %% [markdown]
# ### show encodings

# %%
l1_output = K.function([model.input, K.learning_phase()], [model.layers[1].output])
X_sample_encoded = l1_output([X_sample,1.])[0]

# %%
plt.figure(figsize=(20,2))
for i in range(len(X_sample)):
    plt.subplot(1,len(X_sample),i+1)
    plt.imshow(X_sample_encoded[i].reshape(4,-1), cmap=plt.cm.Greys_r)
    plt.axis("off")

# %% [markdown]
# # Autoencoder for image denoising
#
# observe reconstruction when fed with noisy data

# %%
def add_noise(x, noise_level=.2):
    return x + np.random.normal(size=x.shape)*noise_level

# %%
X_sample_noisy = add_noise(X_sample)
X_pred_noisy   = model.predict(X_sample_noisy)

# %%
plt.figure(figsize=(20,5))
for i in range(len(X_sample_noisy)):
    plt.subplot(2,len(X_sample_noisy),i+1)
    plt.imshow(X_sample_noisy[i].reshape(28,28), cmap=plt.cm.Greys_r)
    plt.axis("off")
    plt.subplot(2,len(X_sample_noisy),len(X_sample_noisy)+i+1)
    plt.imshow(X_pred_noisy[i].reshape(28,28), cmap=plt.cm.Greys_r)
    plt.axis("off")

# %% [markdown]
# but if we train with noisy data reconstruction improves

# %%
n_model = get_model_A(input_dim=X.shape[1], hidden_size=128, code_size=16)
X_train_noisy = add_noise(X_train)

n_model.fit(X_train_noisy, X_train, epochs=100, batch_size=32)
# Out:
# Epoch 1/100
# 1200/1200 [==============================] - 0s 200us/step - loss: 0.1241
# Epoch 2/100
# 1200/1200 [==============================] - 0s 70us/step - loss: 0.0680
# Epoch 3/100
# 1200/1200 [==============================] - 0s 66us/step - loss: 0.0576
# Epoch 4/100
# 1200/1200 [==============================] - 0s 67us/step - loss: 0.0493
# Epoch 5/100
# 1200/1200 [==============================] - 0s 66us/step - loss: 0.0435
# Epoch 6/100
# 1200/1200 [==============================] - 0s 67us/step - loss: 0.0398
# Epoch 7/100
# 1200/1200 [==============================] - 0s 65us/step - loss: 0.0365
# Epoch 8/100
# 1200/1200 [==============================] - 0s 69us/step - loss: 0.0341
# Epoch 9/100
# 1200/1200 [==============================] - 0s 65us/step - loss: 0.0323
# Epoch 10/100
# 1200/1200 [==============================] - 0s 69us/step - loss: 0.0309
# Epoch 11/100
# 1200/1200 [==============================] - 0s 69us/step - loss: 0.0296
# Epoch 12/100
# 1200/1200 [==============================] - 0s 65us/step - loss: 0.0284
# Epoch 13/100
# 1200/1200 [==============================] - 0s 66us/step - loss: 0.0273
# Epoch 14/100
# 1200/1200 [==============================] - 0s 66us/step - loss: 0.0263
# Epoch 15/100
# 1200/1200 [==============================] - 0s 65us/step - loss: 0.0254
# Epoch 16/100
# 1200/1200 [==============================] - 0s 66us/step - loss: 0.0245
# Epoch 17/100
# 1200/1200 [==============================] - 0s 66us/step - loss: 0.0238
# Epoch 18/100
# 1200/1200 [==============================] - 0s 65us/step - loss: 0.0232
# Epoch 19/100
# 1200/1200 [==============================] - 0s 66us/step - loss: 0.0226
# Epoch 20/100
# 1200/1200 [==============================] - 0s 67us/step - loss: 0.0221
# Epoch 21/100
# 1200/1200 [==============================] - 0s 68us/step - loss: 0.0216
# Epoch 22/100
# 1200/1200 [==============================] - 0s 67us/step - loss: 0.0211
# Epoch 23/100
# 1200/1200 [==============================] - 0s 70us/step - loss: 0.0207
# Epoch 24/100
# 1200/1200 [==============================] - 0s 64us/step - loss: 0.0204
# Epoch 25/100
# 1200/1200 [==============================] - 0s 68us/step - loss: 0.0200
# Epoch 26/100
# 1200/1200 [==============================] - 0s 67us/step - loss: 0.0196
# Epoch 27/100
# 1200/1200 [==============================] - 0s 68us/step - loss: 0.0193
# Epoch 28/100
# 1200/1200 [==============================] - 0s 67us/step - loss: 0.0189
# Epoch 29/100
# 1200/1200 [==============================] - 0s 66us/step - loss: 0.0187
# Epoch 30/100
# 1200/1200 [==============================] - 0s 65us/step - loss: 0.0184
# Epoch 31/100
# 1200/1200 [==============================] - 0s 66us/step - loss: 0.0181
# Epoch 32/100
# 1200/1200 [==============================] - 0s 67us/step - loss: 0.0178
# Epoch 33/100
# 1200/1200 [==============================] - 0s 69us/step - loss: 0.0176
# Epoch 34/100
# 1200/1200 [==============================] - 0s 66us/step - loss: 0.0174
# Epoch 35/100
# 1200/1200 [==============================] - 0s 65us/step - loss: 0.0171
# Epoch 36/100
# 1200/1200 [==============================] - 0s 67us/step - loss: 0.0169
# Epoch 37/100
# 1200/1200 [==============================] - 0s 68us/step - loss: 0.0167
# Epoch 38/100
# 1200/1200 [==============================] - 0s 67us/step - loss: 0.0166
# Epoch 39/100
# 1200/1200 [==============================] - 0s 66us/step - loss: 0.0163
# Epoch 40/100
# 1200/1200 [==============================] - 0s 65us/step - loss: 0.0162
# Epoch 41/100
# 1200/1200 [==============================] - 0s 68us/step - loss: 0.0160
# Epoch 42/100
# 1200/1200 [==============================] - 0s 67us/step - loss: 0.0158
# Epoch 43/100
# 1200/1200 [==============================] - 0s 67us/step - loss: 0.0156
# Epoch 44/100
# 1200/1200 [==============================] - 0s 67us/step - loss: 0.0155
# Epoch 45/100
# 1200/1200 [==============================] - 0s 72us/step - loss: 0.0153
# Epoch 46/100
# 1200/1200 [==============================] - 0s 67us/step - loss: 0.0152
# Epoch 47/100
# 1200/1200 [==============================] - 0s 67us/step - loss: 0.0150
# Epoch 48/100
# 1200/1200 [==============================] - 0s 69us/step - loss: 0.0149
# Epoch 49/100
# 1200/1200 [==============================] - 0s 68us/step - loss: 0.0147
# Epoch 50/100
# 1200/1200 [==============================] - 0s 81us/step - loss: 0.0146
# Epoch 51/100
# 1200/1200 [==============================] - 0s 87us/step - loss: 0.0145
# Epoch 52/100
# 1200/1200 [==============================] - 0s 86us/step - loss: 0.0143
# Epoch 53/100
# 1200/1200 [==============================] - 0s 63us/step - loss: 0.0142
# Epoch 54/100
# 1200/1200 [==============================] - 0s 86us/step - loss: 0.0140
# Epoch 55/100
# 1200/1200 [==============================] - 0s 94us/step - loss: 0.0139
# Epoch 56/100
# 1200/1200 [==============================] - 0s 86us/step - loss: 0.0138
# Epoch 57/100
# 1200/1200 [==============================] - 0s 64us/step - loss: 0.0137
# Epoch 58/100
# 1200/1200 [==============================] - 0s 64us/step - loss: 0.0137
# Epoch 59/100
# 1200/1200 [==============================] - 0s 63us/step - loss: 0.0135
# Epoch 60/100
# 1200/1200 [==============================] - 0s 67us/step - loss: 0.0134
# Epoch 61/100
# 1200/1200 [==============================] - 0s 70us/step - loss: 0.0133
# Epoch 62/100
# 1200/1200 [==============================] - 0s 62us/step - loss: 0.0132
# Epoch 63/100
# 1200/1200 [==============================] - 0s 66us/step - loss: 0.0130
# Epoch 64/100
# 1200/1200 [==============================] - 0s 66us/step - loss: 0.0130
# Epoch 65/100
# 1200/1200 [==============================] - 0s 65us/step - loss: 0.0129
# Epoch 66/100
# 1200/1200 [==============================] - 0s 66us/step - loss: 0.0128
# Epoch 67/100
# 1200/1200 [==============================] - 0s 66us/step - loss: 0.0127
# Epoch 68/100
# 1200/1200 [==============================] - 0s 62us/step - loss: 0.0126
# Epoch 69/100
# 1200/1200 [==============================] - 0s 64us/step - loss: 0.0125
# Epoch 70/100
# 1200/1200 [==============================] - 0s 67us/step - loss: 0.0124
# Epoch 71/100
# 1200/1200 [==============================] - 0s 64us/step - loss: 0.0124
# Epoch 72/100
# 1200/1200 [==============================] - 0s 63us/step - loss: 0.0123
# Epoch 73/100
# 1200/1200 [==============================] - 0s 65us/step - loss: 0.0122
# Epoch 74/100
# 1200/1200 [==============================] - 0s 68us/step - loss: 0.0121
# Epoch 75/100
# 1200/1200 [==============================] - 0s 65us/step - loss: 0.0120
# Epoch 76/100
# 1200/1200 [==============================] - 0s 65us/step - loss: 0.0120
# Epoch 77/100
# 1200/1200 [==============================] - 0s 65us/step - loss: 0.0120
# Epoch 78/100
# 1200/1200 [==============================] - 0s 64us/step - loss: 0.0118
# Epoch 79/100
# 1200/1200 [==============================] - 0s 67us/step - loss: 0.0118
# Epoch 80/100
# 1200/1200 [==============================] - 0s 66us/step - loss: 0.0116
# Epoch 81/100
# 1200/1200 [==============================] - 0s 77us/step - loss: 0.0116
# Epoch 82/100
# 1200/1200 [==============================] - 0s 65us/step - loss: 0.0115
# Epoch 83/100
# 1200/1200 [==============================] - 0s 67us/step - loss: 0.0115
# Epoch 84/100
# 1200/1200 [==============================] - 0s 64us/step - loss: 0.0114
# Epoch 85/100
# 1200/1200 [==============================] - 0s 69us/step - loss: 0.0113
# Epoch 86/100
# 1200/1200 [==============================] - 0s 66us/step - loss: 0.0112
# Epoch 87/100
# 1200/1200 [==============================] - 0s 65us/step - loss: 0.0112
# Epoch 88/100
# 1200/1200 [==============================] - 0s 64us/step - loss: 0.0111
# Epoch 89/100
# 1200/1200 [==============================] - 0s 67us/step - loss: 0.0111
# Epoch 90/100
# 1200/1200 [==============================] - 0s 64us/step - loss: 0.0110
# Epoch 91/100
# 1200/1200 [==============================] - 0s 67us/step - loss: 0.0110
# Epoch 92/100
# 1200/1200 [==============================] - 0s 68us/step - loss: 0.0109
# Epoch 93/100
# 1200/1200 [==============================] - 0s 70us/step - loss: 0.0108
# Epoch 94/100
# 1200/1200 [==============================] - 0s 65us/step - loss: 0.0107
# Epoch 95/100
# 1200/1200 [==============================] - 0s 66us/step - loss: 0.0107
# Epoch 96/100
# 1200/1200 [==============================] - 0s 80us/step - loss: 0.0107
# Epoch 97/100
# 1200/1200 [==============================] - 0s 87us/step - loss: 0.0107
# Epoch 98/100
# 1200/1200 [==============================] - 0s 88us/step - loss: 0.0106
# Epoch 99/100
# 1200/1200 [==============================] - 0s 63us/step - loss: 0.0105
# Epoch 100/100
# 1200/1200 [==============================] - 0s 63us/step - loss: 0.0105

# %%
X_sample_noisy = add_noise(X_sample)
X_pred_noisy   = n_model.predict(X_sample_noisy)

plt.figure(figsize=(20,5))
for i in range(len(X_sample_noisy)):
    plt.subplot(2,len(X_sample_noisy),i+1)
    plt.imshow(X_sample_noisy[i].reshape(28,28), cmap=plt.cm.Greys_r)
    plt.axis("off")
    plt.subplot(2,len(X_sample_noisy),len(X_sample_noisy)+i+1)
    plt.imshow(X_pred_noisy[i].reshape(28,28), cmap=plt.cm.Greys_r)
    plt.axis("off")
