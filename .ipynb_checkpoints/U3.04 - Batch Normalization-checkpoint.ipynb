# %%
import tensorflow as tf
from time import time
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import mlutils
reload(mlutils)
# %matplotlib inline
# Out:
# /opt/anaconda/lib/python2.7/site-packages/sklearn/ensemble/weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d

# %% [markdown]
# ### RECOMMENDATION
#
# - close all applications
# - install Maxthon browser http://www.maxthon.com
# - open only VirtualBox and Maxthon
#
#
# ## Batch Normalization
#
# See
#
# - [Batch Normalization: Accelerating Deep Network Training by Reducing Internal Covariate Shift](https://arxiv.org/pdf/1502.03167.pdf)
#
# - [Batch normalization: theory and how to use it with Tensorflow](https://towardsdatascience.com/batch-normalization-theory-and-how-to-use-it-with-tensorflow-1892ca0173ad)
#
# - [CS231n Convolutional Neural Networks](http://cs231n.github.io/neural-networks-2/)

# %% [markdown]
# **We are using a small dataset based on [CIFAR-10](https://www.cs.toronto.edu/~kriz/cifar.html)**

# %%
# !wget -nc https://s3.amazonaws.com/rlx/mini_cifar.h5
# Out:
# File ‘mini_cifar.h5’ already there; not retrieving.

# %%
import h5py
with h5py.File('mini_cifar.h5','r') as h5f:
    x_cifar = h5f["x"][:]
    y_cifar = h5f["y"][:]

# %%
mlutils.show_labeled_image_mosaic(x_cifar, y_cifar)

# %%
print np.min(x_cifar), np.max(x_cifar)
# Out:
# 0.0 1.0

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x_cifar, y_cifar, test_size=.25)
num_classes = len(np.unique(y_train))
print x_train.shape, y_train.shape, x_test.shape, y_test.shape
print "\ndistribution of train classes"
print pd.Series(y_train).value_counts()
print "\ndistribution of test classes"
print pd.Series(y_test).value_counts()
print "\nnum classes", num_classes
# Out:
# (2253, 32, 32, 3) (2253,) (751, 32, 32, 3) (751,)
#
# distribution of train classes
# 2    780
# 0    745
# 1    728
# dtype: int64
#
# distribution of test classes
# 0    260
# 1    246
# 2    245
# dtype: int64
#
# num classes 3

# %% [markdown]
# ## Set up a model with Keras and train

# %%
def get_conv_model_A(num_classes, img_size=32, compile=True):
    def norm_init(shape, dtype=None, partition_info=None):
        return tf.keras.backend.random_normal(shape, mean=0.0, stddev=0.01, dtype=dtype)
    
    tf.reset_default_graph()
    tf.keras.backend.clear_session()
    print "using",num_classes,"classes"
    inputs = tf.keras.Input(shape=(img_size,img_size,3), name="input_1")
    layers = tf.keras.layers.Conv2D(15,(4,4), activation="relu", padding="same", 
                                    kernel_initializer=norm_init,
                                    bias_initializer=norm_init)(inputs)
        
    layers = tf.keras.layers.Flatten()(layers)
    layers = tf.keras.layers.Dense(16, activation=tf.nn.relu, 
                                   kernel_initializer=norm_init,
                                   bias_initializer=norm_init)(layers)
    
    predictions = tf.keras.layers.Dense(num_classes, activation=tf.nn.softmax, name="output_1")(layers)
    model = tf.keras.Model(inputs = inputs, outputs=predictions)
    if compile:
        model.compile(optimizer='adam',
                      loss='sparse_categorical_crossentropy',
                      metrics=['accuracy'])
    return model

# %%
model = get_conv_model_A(num_classes)
model.summary()
print "\n--- weights ---"
for w in model.get_weights():
    print w.shape
# Out:
# using 3 classes
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 32, 32, 3)         0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 32, 32, 15)        735
# _________________________________________________________________
# flatten (Flatten)            (None, 15360)             0
# _________________________________________________________________
# dense (Dense)                (None, 16)                245776
# _________________________________________________________________
# output_1 (Dense)             (None, 3)                 51
# =================================================================
# Total params: 246,562
# Trainable params: 246,562
# Non-trainable params: 0
# _________________________________________________________________
#
# --- weights ---
# (4, 4, 3, 15)
# (15,)
# (15360, 16)
# (16,)
# (16, 3)
# (3,)

# %%
def train(model, x_train, y_train, x_test, y_test, batch_size, epochs, model_name=""):
    model.reset_states()
    model.fit(x_train, y_train, epochs=epochs,
              batch_size=batch_size,
              validation_data=(x_test, y_test))
    metrics = model.evaluate(x_test, y_test)
    return {k:v for k,v in zip (model.metrics_names, metrics)}

# %%
model = get_conv_model_A(num_classes)
train(model, x_train, y_train, x_test, y_test, batch_size=32, epochs=30, model_name="model_A")
# Out:
# using 3 classes
# Train on 2253 samples, validate on 751 samples
# Epoch 1/30
# 2253/2253 [==============================] - 3s 1ms/step - loss:
30
# 2253/2253 [==============================] - 2s 1ms/step - loss: 0.2555 - acc: 0.9077 - val_loss: 0.8004 - val_acc: 0.7097
# Epoch 25/30
# 2253/2253 [==============================] - 2s 1ms/step - loss: 0.2403 - acc: 0.9090 - val_loss: 0.8348 - val_acc: 0.7097
# Epoch 26/30
# 2253/2253 [==============================] - 2s 948us/step - loss: 0.2233 - acc: 0.9259 - val_loss: 0.8965 - val_acc: 0.6991
# Epoch 27/30
# 2253/2253 [==============================] - 2s 973us/step - loss: 0.2214 - acc: 0.9223 - val_loss: 0.8496 - val_acc: 0.6951
# Epoch 28/30
# 2253/2253 [==============================] - 2s 930us/step - loss: 0.1915 - acc: 0.9379 - val_loss: 0.8909 - val_acc: 0.7177
# Epoch 29/30
# 2253/2253 [==============================] - 2s 895us/step - loss: 0.1781 - acc: 0.9472 - val_loss: 0.9084 - val_acc: 0.7031
# Epoch 30/30
# 2253/2253 [==============================] - 2s 980us/step - loss: 0.1736 - acc: 0.9512 - val_loss: 0.9362 - val_acc: 0.7057
# 751/751 [==============================] - 0s 371us/step
# {'acc': 0.7057256992266435, 'loss': 0.9362054363230414}

# %%
def plot_hist(model):
    plt.plot(model.history.history["acc"], label="acc")
    plt.plot(model.history.history["val_acc"], label="val_acc")
    plt.grid()
    plt.legend();
    plt.xlabel("training step")
    plt.ylabel("accuracy")
    plt.ylim(0.4,1.05)

# %%
plot_hist(model)

# %% [markdown]
# ## Standardize full dataset pixel-wise
#
# Given:
#
# - $X^{i}$: image $i$
# - $X^{i}_{j|k}$: channel $k$ of pixel $j$ in image $i$
# - $S^i$: image $i$ standardized
#
# In pixel wise standardization, each pixel has zero mean and std=1 across the dataset:
#
# - $\mu_{j|k} = \frac{1}{N}\sum_{i=0}^{N-1}X^{i}_{j|k}$
# - $\sigma_{j|k} = \frac{1}{N}\sum_{i=0}^{N-1}(X^{i}_{j|k}-\mu_{j|k})^2$
#
# So that:
#
# $$S^{i}_{j|k} = \frac{1}{\sigma_{j|k}}(X^{i}_{j|k} - \mu_{j|k})$$
#
# Observe that we compute one $\mu$ and one $\sigma$ per each pixel and channel across the dataset.

# %%
from sklearn.preprocessing import StandardScaler

sx_train = StandardScaler().fit_transform(x_train.reshape(-1,32*32*3)).reshape(-1,32,32,3)
sx_test  = StandardScaler().fit_transform(x_test.reshape(-1,32*32*3)).reshape(-1,32,32,3)

# %%
np.min(sx_train), np.max(sx_train)
# Out:
# (-2.448690507303215, 2.4193689284849462)

# %%
x_train.shape, sx_train.shape
# Out:
# ((2253, 32, 32, 3), (2253, 32, 32, 3))

# %%
smodel = get_conv_model_A(num_classes)
train(smodel, sx_train, y_train, sx_test, y_test, batch_size=32, epochs=30, model_name="model_A")
# Out:
# using 3 classes
# Train on 2253 samples, validate on 751 samples
# Epoch 1/30
# 2253/2253 [==============================] - 4s 2ms/step - loss: 0.8801 - acc: 0.5881 - val_loss: 0.7955 - val_acc: 0.6418
# Epoch 2/30
# 2253/2253 [==============================] - 3s 2ms/step - loss: 0.6720 - acc: 0.6982 - val_loss: 0.7157 - val_acc: 0.6897
# Epoch 3/30
# 2253/2253 [==============================] - 4s 2ms/step - loss: 0.5786 - acc: 0.7603 - val_loss: 0.7117 - val_acc: 0.6951
# Epoch 4/30
# 2253/2253 [==============================] - 3s 1ms/step - loss: 0
/step - loss: 0.0039 - acc: 1.0000 - val_loss: 1.5812 - val_acc: 0.7350
# 751/751 [==============================] - 0s 249us/step
# {'acc': 0.7350199737656767, 'loss': 1.5812440553454363}

# %%
plt.figure(figsize=(10,3))
plt.subplot(121)
plot_hist(model); plt.ylim(0.5,1); plt.title("raw images")
plt.subplot(122)
plot_hist(smodel); plt.ylim(0.5,1); plt.title("pixel wise standardization")
# Out:
# Text(0.5,1,'pixel wise standardization')

# %% [markdown]
# ## Standardize each image
#
# each image has zero mean and std=1
#
# In image wise standardization, each image has zero mean and std=1 across the dataset:
#
# - $\mu^i = \frac{1}{n_j \times n_k}\sum_{j,k}X^{i}_{j|k}$
# - $\sigma^i = \frac{1}{n_j \times n_k}\sum_{j,k}(X^{i}_{j|k}-\mu^i)^2$
#
# where $n_j$ and $n_k$ are the number of pixels and the number of channels in im age $i$.
#
# So that:
#
# $$S^{i}_{j|k} = \frac{1}{\sigma^i}(X^{i}_{j|k} - \mu^i)$$

# %%
sc = StandardScaler()
sx_train = np.r_[[(i-np.mean(i))/np.std(i) for i in x_train]]
sx_test = np.r_[[(i-np.mean(i))/np.std(i) for i in x_test]]

np.min(sx_train), np.max(sx_train)
# Out:
# (-7.546909042833099, 6.537064736522712)

# %%
s2model = get_conv_model_A(num_classes)
train(s2model, sx_train, y_train, sx_test, y_test, batch_size=32, epochs=30, model_name="model_A")
# Out:
# using 3 classes
# Train on 2253 samples, validate on 751 samples
# Epoch 1/30
# 2253/2253 [==============================] - 3s 1ms/step - loss: 0.8475 - acc: 0.6014 - val_loss: 0.7558 - val_acc: 0.6897
# Epoch 2/30
# 2253/2253 [==============================] - 3s 1ms/step - loss: 0.6727 - acc: 0.7217 - val_loss: 0.7273 - val_acc: 0.6924
# Epoch 3/30
# 2253/2253 [==============================] - 2s 884us/step - loss: 0.5707 - acc: 0.7683 - val_loss: 0.6862 - val_acc: 0.7190
# Epoch 4/30
# 2253/2253 [==============================] - 3s 1ms/step - loss: 0.4756 - acc: 0.8162 - val_loss: 0.6983 - val_acc: 0.7111
# Epoch 5/30
# 2253/2253 [==============================] - 2s 1ms/step - loss: 0.3998 - acc: 0.8380 - val_loss: 0.7422 - val_acc: 0.7111
# Epoch 6/30
# 2253/2253 [==============================] - 2s 901us/step - loss: 0.3176 - acc: 0.8771 - val_loss: 0.7527 - val_acc: 0.7350
# Epoch 7/30
# 2253/2253 [==============================] - 2s 945us/step - loss: 0.2463 - acc: 0.9086 - val_loss: 0.9747 - val_acc: 0.7217
# Epoch 8/30
# 2253/2253 [==============================] - 4s 2ms/step - loss: 0.1948 - acc: 0.9308 - val_loss: 0.8673 - val_acc: 0.7071
# Epoch 9/30
# 2253/2253 [==============================] - 2s 1ms/step - loss: 0.1716 - acc: 0.9383 - val_loss: 0.9211 - val_acc: 0.7150
# Epoch 10/30
# 2253/2253 [==============================] - 2s 1ms/step - loss: 0.1473 - acc: 0.9494 - val_loss: 1.1036 - val_acc: 0.7230
# Epoch 11/30
# 2253/2253 [==============================] - 2s 911us/step - loss: 0.1093 - acc: 0.9645 - val_loss: 1.0058 - val_acc: 0.7244
# Epoch 12/30
# 2253/2253 [==============================] - 2s 1ms/step - loss: 0.0772 - acc: 0.9769 - val_loss: 1.0847 - val_acc: 0.7284
# Epoch 13/30
# 2253/2253 [==============================] - 2s 956us/step - loss: 0.0604 - acc: 0.9845 - val_loss: 1.2931 - val_acc: 0.7244
# Epoch 14/30
# 2253/2253 [==============================] - 2s 928us/step - loss: 0.0949 - acc: 0.9654 - val_loss: 1.2102 - val_acc: 0.7164
# Epoch 15/30
# 2253/2253 [==============================] - 2s 945us/step - loss: 0.0519 - acc: 0.9871 - val_loss: 1.2188 - val_acc: 0.7257
# Epoch 16/30
# 2253/2253 [==============================] - 2s 927us/step - loss: 0.0288 - acc: 0.9942 - val_loss: 1.3104 - val_acc: 0.7284
# Epoch 17/30
# 2253/2253 [==============================] - 2s 963us/step - loss: 0.0168 - acc: 0.9982 - val_loss: 1.3332 - val_acc: 0.7350
# Epoch 18/30
# 2253/2253 [==============================] - 2s 913us/step - loss: 0.0128 - acc: 0.9982 - val_loss: 1.4259 - val_acc: 0.7364
# Epoch 19/30
# 2253/2253 [==============================] - 2s 953us/step - loss: 0.0094 - acc: 0.9996 - val_loss: 1.4346 - val_acc: 0.7257
# Epoch 20/30
# 2253/2253 [==============================] - 2s 911us/step - loss: 0.0069 - acc: 0.9996 - val_loss: 1.4472 - val_acc: 0.7270
# Epoch 21/30
# 2253/2253 [==============================] - 2s 1ms/step - loss: 0.0054 - acc: 0.9996 - val_loss: 1.4886 - val_acc: 0.7337
# Epoch 22/30
# 2253/2253 [==============================] - 2s 914us/step - loss: 0.0047 - acc: 0.9996 - val_loss: 1.4861 - val_acc: 0.7377
# Epoch 23/30
# 2253/2253 [==============================] - 2s 912us/step - loss: 0.0041 - acc: 0.9996 - val_loss: 1.5198 - val_acc: 0.7324
# Epoch 24/30
# 2253/2253 [==============================] - 2s 912us/step - loss: 0.0036 - acc: 0.9996 - val_loss: 1.5575 - val_acc: 0.7337
# Epoch 25/30
# 2253/2253 [==============================] - 2s 962us/step - loss: 0.0034 - acc: 0.9996 - val_loss: 1.5857 - val_acc: 0.7297
# Epoch 26/30
# 2253/2253 [==============================] - 2s 943us/step - loss: 0.0031 - acc: 0.9996 - val_loss: 1.5717 - val_acc: 0.7377
# Epoch 27/30
# 2253/2253 [==============================] - 2s 991us/step - loss: 0.0028 - acc: 0.9996 - val_loss: 1.6030 - val_acc: 0.7284
# Epoch 28/30
# 2253/2253 [==============================] - 2s 975us/step - loss: 0.0026 - acc: 0.9996 - val_loss: 1.6196 - val_acc: 0.7310
# Epoch 29/30
# 2253/2253 [==============================] - 2s 1ms/step - loss: 0.0023 - acc: 0.9996 - val_loss: 1.6373 - val_acc: 0.7377
# Epoch 30/30
# 2253/2253 [==============================] - 2s 1ms/step - loss: 0.0021 - acc: 0.9996 - val_loss: 1.6496 - val_acc: 0.7310
# 751/751 [==============================] - 0s 402us/step
# {'acc': 0.7310252997592667, 'loss': 1.649638355492593}

# %% [markdown]
# Observe how accuracy (on train data) raises faster. Variance is still high since we have a small dataset.
#
# - why does it raise faster on pixel-wise standardization?
# - why does it raise even faster with image-wise standardization?
#
# In both cases we are helping optimization by keeping activations centered in zero and having more meaningful gradients. In image-wise standardization we ensure this property tighter at each image.

# %%
plt.figure(figsize=(15,3))
plt.subplot(131)
plot_hist(model); plt.ylim(0.5,1.06); plt.title("raw images")
plt.subplot(132)
plot_hist(smodel); plt.ylim(0.5,1.05); plt.title("pixel wise standardization")
plt.subplot(133)
plot_hist(s2model); plt.ylim(0.5,1.05); plt.title("image wise standardization")
# Out:
# Text(0.5,1,'image wise standardization')

# %% [markdown]
# ## ZCA whitening

# %%
def zca_whitening(inputs):
    sigma = np.dot(inputs, inputs.T)/inputs.shape[1] #Correlation matrix
    U,S,V = np.linalg.svd(sigma) #Singular Value Decomposition
    epsilon = 0.1                #Whitening constant, it prevents division by zero
    ZCAMatrix = np.dot(np.dot(U, np.diag(1.0/np.sqrt(np.diag(S) + epsilon))), U.T)                     #ZCA Whitening matrix
    return np.dot(ZCAMatrix, inputs)   #Data whitening

# %%
sx_train = np.r_[[(i-np.mean(i))/np.std(i) for i in x_train]]
sx_test = np.r_[[(i-np.mean(i))/np.std(i) for i in x_test]]

zx_train = np.r_[[zca_whitening(i.reshape(1,-1)).reshape(i.shape) for i in sx_train]]
zx_test  = np.r_[[zca_whitening(i.reshape(1,-1)).reshape(i.shape) for i in sx_test]]

# %%
from sklearn.preprocessing import MinMaxScaler
mm = MinMaxScaler()
#zx_train = np.r_[[mm.fit_transform(i.reshape(-1,1)).reshape(i.shape) for i in zx_train]]
#zx_test = np.r_[[mm.fit_transform(i.reshape(-1,1)).reshape(i.shape) for i in zx_test]]

# %%
idxs = np.random.permutation(100)[:10]

# %%
mlutils.show_labeled_image_mosaic(x_train, y_train, idxs=idxs)

# %%
mlutils.show_labeled_image_mosaic(zx_train, y_train, idxs=idxs)

# %%
zmodel = get_conv_model_A(num_classes)
train(zmodel, zx_train, y_train, zx_test, y_test, batch_size=32, epochs=30, model_name="model_A")
# Out:
# using 3 classes
# Train on 2253 samples, validate on 751 samples
# Epoch 1/30
# 2253/2253 [==============================] - 3s 1ms/step - loss: 0.8596 - acc: 0.6099 - val_loss: 0.7161 - val_acc: 0.6924
# Epoch 2/30
# 2253/2253 [==============================] - 2s 1ms/step - loss: 0.6679 - acc: 0.7062 - val_loss: 0.6998 - val_acc: 0.7004
# Epoch 3/30
# 2253/2253 [==============================] - 2s 964us/step - loss: 0.5431 - acc: 0.7745 - val_loss: 0.6933 - val_acc: 0.7230
# Epoch 4/30
# 2253/2253 [==============================] - 2s 873us/step - loss: 0.4609 - acc: 0.8127 - val_loss: 0.6887 - val_acc: 0.7217
# Epoch 5/30
# 2253/2253 [==============================] - 2s 914us/step - loss: 0.3668 - acc: 0.8571 - val_loss: 0.7369 - val_acc: 0.7217
# Epoch 6/30
# 2253/2253 [==============================] - 2s 896us/step - loss: 0.2933 - acc: 0.8930 - val_loss: 0.8199 - val_acc: 0.7257
# Epoch 7/30
# 2253/2253 [==============================] - 2s 890us/step - loss: 0.2446 - acc: 0.9095 - val_loss: 0.7641 - val_acc: 0.7177
# Epoch 8/30
# 2253/2253 [==============================] - 2s 867us/step - loss: 0.1933 - acc: 0.9321 - val_loss: 0.8245 - val_acc: 0.7350
# Epoch 9/30
# 2253/2253 [==============================] - 2s 930us/step - loss: 0.1502 - acc: 0.9490 - val_loss: 0.8328 - val_acc: 0.7297
# Epoch 10/30
# 2253/2253 [==============================] - 2s 951us/step - loss: 0.1007 - acc: 0.9711 - val_loss: 0.9148 - val_acc: 0.7417
# Epoch 11/30
# 2253/2253 [==============================] - 2s 902us/step - loss: 0.0746 - acc: 0.9769 - val_loss: 0.9786 - val_acc: 0.7390
# Epoch 12/30
# 2253/2253 [==============================] - 3s 1ms/step - loss: 0.0485 - acc: 0.9885 - val_loss: 1.0889 - val_acc: 0.7350
# Epoch 13/30
# 2253/2253 [==============================] - 2s 1ms/step - loss: 0.0423 - acc: 0.9916 - val_loss: 1.0654 - val_acc: 0.7417
# Epoch 14/30
# 2253/2253 [==============================] - 2s 969us/step - loss: 0.0278 - acc: 0.9951 - val_loss: 1.2055 - val_acc: 0.7417
# Epoch 15/30
# 2253/2253 [==============================] - 2s 958us/step - loss: 0.0169 - acc: 0.9996 - val_loss: 1.1427 - val_acc: 0.7483
# Epoch 16/30
# 2253/2253 [==============================] - 2s 981us/step - loss: 0.0107 - acc: 1.0000 - val_loss: 1.2257 - val_acc: 0.7390
# Epoch 17/30
# 2253/2253 [==============================] - 2s 971us/step - loss: 0.0080 - acc: 1.0000 - val_loss: 1.2429 - val_acc: 0.7417
# Epoch 18/30
# 2253/2253 [==============================] - 3s 1ms/step - loss: 0.0069 - acc: 1.0000 - val_loss: 1.3030 - val_acc: 0.7417
# Epoch 19/30
# 2253/2253 [==============================] - 2s 961us/step - loss: 0.0051 - acc: 1.0000 - val_loss: 1.3295 - val_acc: 0.7470
# Epoch 20/30
# 2253/2253 [==============================] - 2s 956us/step - loss: 0.0042 - acc: 1.0000 - val_loss: 1.3236 - val_acc: 0.7457
# Epoch 21/30
# 2253/2253 [==============================] - 2s 978us/step - loss: 0.0034 - acc: 1.0000 - val_loss: 1.3440 - val_acc: 0.7443
# Epoch 22/30
# 2253/2253 [==============================] - 2s 1ms/step - loss: 0.0030 - acc: 1.0000 - val_loss: 1.3686 - val_acc: 0.7457
# Epoch 23/30
# 2253/2253 [==============================] - 2s 984us/step - loss: 0.0026 - acc: 1.0000 - val_loss: 1.4009 - val_acc: 0.7470
# Epoch 24/30
# 2253/2253 [==============================] - 3s 1ms/step - loss: 0.0022 - acc: 1.0000 - val_loss: 1.4271 - val_acc: 0.7457
# Epoch 25/30
# 2253/2253 [==============================] - 2s 1ms/step - loss: 0.0020 - acc: 1.0000 - val_loss: 1.4316 - val_acc: 0.7457
# Epoch 26/30
# 2253/2253 [==============================] - 2s 1ms/step - loss: 0.0018 - acc: 1.0000 - val_loss: 1.4638 - val_acc: 0.7470
# Epoch 27/30
# 2253/2253 [==============================] - 2s 1ms/step - loss: 0.0016 - acc: 1.0000 - val_loss: 1.4699 - val_acc: 0.7457
# Epoch 28/30
# 2253/2253 [==============================] - 3s 1ms/step - loss: 0.0014 - acc: 1.0000 - val_loss: 1.4848 - val_acc: 0.7430
# Epoch 29/30
# 2253/2253 [==============================] - 2s 994us/step - loss: 0.0013 - acc: 1.0000 - val_loss: 1.5053 - val_acc: 0.7443
# Epoch 30/30
# 2253/2253 [==============================] - 2s 974us/step - loss: 0.0012 - acc: 1.0000 - val_loss: 1.5210 - val_acc: 0.7430
# 751/751 [==============================] - 0s 368us/step
# {'acc': 0.7430093211435606, 'loss': 1.5209514784431966}

# %%
plt.figure(figsize=(15,3))
plt.subplot(141)
plot_hist(model); plt.ylim(0.5,1); plt.title("raw images")
plt.subplot(142)
plot_hist(smodel); plt.ylim(0.5,1); plt.title("pixel wise standardization")
plt.subplot(143)
plot_hist(s2model); plt.ylim(0.5,1); plt.title("image wise standardization")
plt.subplot(144)
plot_hist(zmodel); plt.ylim(0.5,1); plt.title("zca whitening")
# Out:
# Text(0.5,1,'zca whitening')

# %%
plt.plot(model.history.history["acc"], label="raw");
plt.plot(smodel.history.history["acc"], label="pixel");
plt.plot(s2model.history.history["acc"], label="image");
plt.plot(zmodel.history.history["acc"], label="zca");
plt.grid();
plt.legend();
plt.xlabel("training epoch")
plt.ylabel("accuracy in train")
# Out:
# Text(0,0.5,'accuracy in train')

# %%
def get_conv_model_B(num_classes, img_size=32, compile=True):
    tf.reset_default_graph()
    tf.keras.backend.clear_session()
    print "using",num_classes,"classes"
    inputs = tf.keras.Input(shape=(img_size,img_size,3), name="input_1")
    layers = tf.keras.layers.Conv2D(15,(4,4), activation="relu")(inputs)
    layers = tf.keras.layers.BatchNormalization()(layers)
    layers = tf.keras.layers.Flatten()(layers)
    layers = tf.keras.layers.Dense(16, activation=tf.nn.relu)(layers)
    predictions = tf.keras.layers.Dense(num_classes, activation=tf.nn.softmax, name="output_1")(layers)
    model = tf.keras.Model(inputs = inputs, outputs=predictions)
    if compile:
        model.compile(optimizer='adam',
                      loss='sparse_categorical_crossentropy',
                      metrics=['accuracy'])
    return model

# %%
bmodel = get_conv_model_B(num_classes)
train(bmodel, x_train, y_train, x_test, y_test, batch_size=32, epochs=30, model_name="model_A")
# Out:
# using 3 classes
# Train on 2253 samples, validate on 751 samples
# Epoch 1/30
# 2253/2253 [==============================] - 3s 1ms/step - loss: 1.0563 - acc: 0.5846 - val_loss: 0.9709 - val_acc: 0.5766
# Epoch 2/30
# 2253/2253 [==============================] - 2s 1ms/step - loss: 0.6118 - acc: 0.7395 - val_loss: 0.8799 - val_acc: 0.6578
# Epoch 3/30
# 2253/2253 [==============================] - 2s 1ms/step - loss: 0.4246 - acc: 0.8238 - val_loss: 0.8702 - val_acc: 0.6631
# Epoch 4/30
# 2253/2253 [==============================] - 3s 1ms/step - loss: 0.2820 - acc: 0.8957 - val_loss: 0.7512 - val_acc: 0.7044
# Epoch 5/30
# 2253/2253 [==============================] - 3s 1ms/step - loss: 0.1806 - acc: 0.9387 - val_loss: 0.7042 - val_acc: 0.7124
# Epoch 6/30
# 2253/2253 [==============================] - 3s 1ms/step - loss: 0.1244 - acc: 0.9636 - val_loss: 0.7960 - val_acc: 0.6818
# Epoch 7/30
# 2253/2253 [==============================] - 3s 1ms/step - loss: 0.0844 - acc: 0.9765 - val_loss: 0.7494 - val_acc: 0.7417
# Epoch 8/30
# 2253/2253 [==============================] - 3s 1ms/step - loss: 0.0590 - acc: 0.9836 - val_loss: 0.8889 - val_acc: 0.7270
# Epoch 9/30
# 2253/2253 [==============================] - 2s 1ms/step - loss: 0.0437 - acc: 0.9880 - val_loss: 1.0037 - val_acc: 0.7124
# Epoch 10/30
# 2253/2253 [==============================] - 3s 1ms/step - loss: 0.0316 - acc: 0.9925 - val_loss: 1.0175 - val_acc: 0.7297
# Epoch 11/30
# 2253/2253 [==============================] - 3s 1ms/step - loss: 0.0247 - acc: 0.9947 - val_loss: 1.3656 - val_acc: 0.7097
# Epoch 12/30
# 2253/2253 [==============================] - 3s 1ms/step - loss: 0.0144 - acc: 0.9973 - val_loss: 1.1737 - val_acc: 0.7430
# Epoch 13/30
# 2253/2253 [==============================] - 3s 1ms/step - loss: 0.0085 - acc: 0.9982 - val_loss: 1.1993 - val_acc: 0.7457
# Epoch 14/30
# 2253/2253 [==============================] - 2s 1ms/step - loss: 0.0072 - acc: 0.9982 - val_loss: 1.2171 - val_acc: 0.7483
# Epoch 15/30
# 2253/2253 [==============================] - 2s 1ms/step - loss: 0.0054 - acc: 0.9982 - val_loss: 1.2515 - val_acc: 0.7483
# Epoch 16/30
# 2253/2253 [==============================] - 2s 1ms/step - loss: 0.0044 - acc: 0.9982 - val_loss: 1.2583 - val_acc: 0.7403
# Epoch 17/30
# 2253/2253 [==============================] - 3s 1ms/step - loss: 0.0042 - acc: 0.9982 - val_loss: 1.2965 - val_acc: 0.7483
# Epoch 18/30
# 2253/2253 [==============================] - 3s 1ms/step - loss: 0.0039 - acc: 0.9982 - val_loss: 1.2759 - val_acc: 0.7497
# Epoch 19/30
# 2253/2253 [==============================] - 3s 1ms/step - loss: 0.0034 - acc: 0.9982 - val_loss: 1.3354 - val_acc: 0.7430
# Epoch 20/30
# 2253/2253 [==============================] - 3s 1ms/step - loss: 0.0039 - acc: 0.9982 - val_loss: 1.3163 - val_acc: 0.7443
# Epoch 21/30
# 2253/2253 [==============================] - 3s 1ms/step - loss: 0.0032 - acc: 0.9982 - val_loss: 1.3354 - val_acc: 0.7497
# Epoch 22/30
# 2253/2253 [==============================] - 3s 1ms/step - loss: 0.0029 - acc: 0.9982 - val_loss: 1.3497 - val_acc: 0.7563
# Epoch 23/30
# 2253/2253 [==============================] - 3s 1ms/step - loss: 0.0028 - acc: 0.9982 - val_loss: 1.3518 - val_acc: 0.7443
# Epoch 24/30
# 2253/2253 [==============================] - 3s 1ms/step - loss: 0.0029 - acc: 0.9982 - val_loss: 1.3613 - val_acc: 0.7523
# Epoch 25/30
# 2253/2253 [==============================] - 3s 1ms/step - loss: 0.0026 - acc: 0.9982 - val_loss: 1.3818 - val_acc: 0.7497
# Epoch 26/30
# 2253/2253 [==============================] - 3s 1ms/step - loss: 0.0025 - acc: 0.9982 - val_loss: 1.3856 - val_acc: 0.7563
# Epoch 27/30
# 2253/2253 [==============================] - 3s 1ms/step - loss: 0.0024 - acc: 0.9982 - val_loss: 1.3887 - val_acc: 0.7470
# Epoch 28/30
# 2253/2253 [==============================] - 3s 1ms/step - loss: 0.0024 - acc: 0.9982 - val_loss: 1.4043 - val_acc: 0.7497
# Epoch 29/30
# 2253/2253 [==============================] - 3s 1ms/step - loss: 0.0025 - acc: 0.9982 - val_loss: 1.4166 - val_acc: 0.7523
# Epoch 30/30
# 2253/2253 [==============================] - 3s 1ms/step - loss: 0.0023 - acc: 0.9982 - val_loss: 1.4215 - val_acc: 0.7510
# 751/751 [==============================] - 0s 439us/step
# {'acc': 0.7509986686801784, 'loss': 1.4214608296255933}

# %%
plt.plot(model.history.history["acc"], label="raw");
plt.plot(smodel.history.history["acc"], label="pixel");
plt.plot(s2model.history.history["acc"], label="image");
plt.plot(zmodel.history.history["acc"], label="zca");
plt.plot(bmodel.history.history["acc"], label="batch");
plt.grid();
plt.legend();
plt.xlabel("training epoch")
plt.ylabel("accuracy in train")
# Out:
# Text(0,0.5,'accuracy in train')

# %% [markdown]
# observe that batch normalization by itself is, in this case, enough

# %%
bzmodel = get_conv_model_B(num_classes)
train(bzmodel, zx_train, y_train, zx_test, y_test, batch_size=32, epochs=30, model_name="model_A")
# Out:
# using 3 classes
# Train on 2253 samples, validate on 751 samples
# Epoch 1/30
# 2253/2253 [==============================] - 3s 1ms/step - loss: 1.1093 - acc: 0.5903 - val_loss: 0.8741 - val_acc: 0.6245
# Epoch 2/30
# 2253/2253 [==============================] - 3s 1ms/step - loss: 0.6243 - acc: 0.7501 - val_loss: 0.7376 - val_acc: 0.7124
# Epoch 3/30
# 2253/2253 [==============================] - 2s 1ms/step - loss: 0.4017 - acc: 0.8336 - val_loss: 0.7283 - val_acc: 0.7124
# Epoch 4/30
# 2253/2253 [==============================] - 2s 1ms/step - loss: 0.2639 - acc: 0.8984 - val_loss: 0.7455 - val_acc: 0.7230
# Epoch 5/30
# 2253/2253 [==============================] - 2s 1ms/step - loss: 0.2031 - acc: 0.9232 - val_loss: 0.8948 - val_acc: 0.7044
# Epoch 6/30
# 2253/2253 [==============================] - 2s 1ms/step - loss: 0.1429 - acc: 0.9481 - val_loss: 0.8634 - val_acc: 0.7297
# Epoch 7/30
# 2253/2253 [==============================] - 2s 1ms/step - loss: 0.0857 - acc: 0.9760 - val_loss: 0.9803 - val_acc: 0.7177
# Epoch 8/30
# 2253/2253 [==============================] - 3s 1ms/step - loss: 0.0514 - acc: 0.9893 - val_loss: 1.1010 - val_acc: 0.7284
# Epoch 9/30
# 2253/2253 [==============================] - 2s 1ms/step - loss: 0.0359 - acc: 0.9942 - val_loss: 1.1235 - val_acc: 0.7217
# Epoch 10/30
# 2253/2253 [==============================] - 2s 1ms/step - loss: 0.0205 - acc: 0.9969 - val_loss: 1.2577 - val_acc: 0.7204
# Epoch 11/30
# 2253/2253 [==============================] - 2s 1ms/step - loss: 0.0122 - acc: 0.9987 - val_loss: 1.2835 - val_acc: 0.7310
# Epoch 12/30
# 2253/2253 [==============================] - 3s 1ms/step - loss: 0.0085 - acc: 0.9991 - val_loss: 1.3432 - val_acc: 0.7297
# Epoch 13/30
# 2253/2253 [==============================] - 3s 1ms/step - loss: 0.0066 - acc: 0.9987 - val_loss: 1.3762 - val_acc: 0.7284
# Epoch 14/30
# 2253/2253 [==============================] - 2s 1ms/step - loss: 0.0048 - acc: 0.9991 - val_loss: 1.3729 - val_acc: 0.7284
# Epoch 15/30
# 2253/2253 [==============================] - 2s 1ms/step - loss: 0.0040 - acc: 0.9991 - val_loss: 1.4201 - val_acc: 0.7337
# Epoch 16/30
# 2253/2253 [==============================] - 2s 1ms/step - loss: 0.0033 - acc: 0.9991 - val_loss: 1.4630 - val_acc: 0.7217
# Epoch 17/30
# 2253/2253 [==============================] - 2s 1ms/step - loss: 0.0029 - acc: 0.9991 - val_loss: 1.4708 - val_acc: 0.7270
# Epoch 18/30
# 2253/2253 [==============================] - 2s 1ms/step - loss: 0.0027 - acc: 0.9991 - val_loss: 1.4713 - val_acc: 0.7257
# Epoch 19/30
# 2253/2253 [==============================] - 2s 1ms/step - loss: 0.0023 - acc: 0.9996 - val_loss: 1.4821 - val_acc: 0.7270
# Epoch 20/30
# 2253/2253 [==============================] - 3s 1ms/step - loss: 0.0022 - acc: 0.9996 - val_loss: 1.5002 - val_acc: 0.7244
# Epoch 21/30
# 2253/2253 [==============================] - 2s 1ms/step - loss: 0.0021 - acc: 0.9996 - val_loss: 1.5198 - val_acc: 0.7257
# Epoch 22/30
# 2253/2253 [==============================] - 2s 1ms/step - loss: 0.0018 - acc: 0.9996 - val_loss: 1.5218 - val_acc: 0.7284
# Epoch 23/30
# 2253/2253 [==============================] - 2s 1ms/step - loss: 0.0017 - acc: 0.9991 - val_loss: 1.5455 - val_acc: 0.7257
# Epoch 24/30
# 2253/2253 [==============================] - 2s 1ms/step - loss: 0.0016 - acc: 0.9996 - val_loss: 1.5515 - val_acc: 0.7257
# Epoch 25/30
# 2253/2253 [==============================] - 2s 1ms/step - loss: 0.0015 - acc: 0.9991 - val_loss: 1.5683 - val_acc: 0.7284
# Epoch 26/30
# 2253/2253 [==============================] - 2s 1ms/step - loss: 0.0015 - acc: 0.9991 - val_loss: 1.5900 - val_acc: 0.7257
# Epoch 27/30
# 2253/2253 [==============================] - 2s 1ms/step - loss: 0.0015 - acc: 0.9991 - val_loss: 1.6021 - val_acc: 0.7297
# Epoch 28/30
# 2253/2253 [==============================] - 2s 1ms/step - loss: 0.0014 - acc: 0.9991 - val_loss: 1.6036 - val_acc: 0.7270
# Epoch 29/30
# 2253/2253 [==============================] - 2s 1ms/step - loss: 0.0013 - acc: 0.9996 - val_loss: 1.6097 - val_acc: 0.7270
# Epoch 30/30
# 2253/2253 [==============================] - 2s 1ms/step - loss: 0.0012 - acc: 0.9996 - val_loss: 1.5991 - val_acc: 0.7257
# 751/751 [==============================] - 0s 304us/step
# {'acc': 0.7256990683062893, 'loss': 1.5990959909086062}

# %%
plt.plot(model.history.history["acc"], label="raw");
plt.plot(smodel.history.history["acc"], label="pixel");
plt.plot(s2model.history.history["acc"], label="image");
plt.plot(zmodel.history.history["acc"], label="zca");
plt.plot(bmodel.history.history["acc"], label="batch");
plt.plot(bzmodel.history.history["acc"], label="zbatch");
plt.grid();
plt.legend();
plt.xlabel("training epoch")
plt.ylabel("accuracy in train")
# Out:
# Text(0,0.5,'accuracy in train')
